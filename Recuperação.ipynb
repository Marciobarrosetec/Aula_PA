# %% [markdown]
# <a href="https://colab.research.google.com/github/Marciobarrosetec/Aula_PA/blob/main/Recupera%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Função soma simples
#
# Crie uma função soma(a, b) que retorna a soma de dois números informados pelo usuário.

# %% [markdown]
# 2. Verificar número par
#
# Faça uma função eh_par(n) que retorna True se o número for par e False caso contrário.

# %% [markdown]
# 3. Cálculo da média
#
# Crie uma função media(lista) que recebe uma lista de números e retorna a média.

# %% [markdown]
# 4. Converter temperatura
#
# Crie uma função celsius_para_fahrenheit(c) que retorna a conversão para Fahrenheit.

# %% [markdown]
# 5. Contar vogais
#
# Escreva uma função conta_vogais(texto) que retorna quantas vogais existem na string.

# %% [markdown]
# 6. Maior de três números
#
# Crie uma função maior(a, b, c) que retorna o maior dos três valores.

# %% [markdown]
# 7. Fatorial simples
#
# Crie uma função fatorial(n) que calcula o fatorial de um número (pode ser com for mesmo).

# %% [markdown]
# 8. Verificar palíndromo
#
# Crie a função eh_palindromo(texto) que retorna True se a palavra for um palíndromo.

# %% [markdown]
# 9. Gerar uma tabuada
#
# Crie uma função tabuada(n) que imprime a tabuada do número escolhido.

# %% [markdown]
# 10. Soma apenas dos pares de uma lista
#
# Faça uma função soma_pares(lista) que soma apenas os números pares da lista recebida.
